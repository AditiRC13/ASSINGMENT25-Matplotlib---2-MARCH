# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Matplotlib is a popular data visualization library in Python. It provides a wide range of tools to create static, animated, and interactive plots in Python. Matplotlib is widely used for visualizing data in the fields of science, engineering, finance, and many others.

# %% [markdown]
# Some of the reasons why Matplotlib is used are:

# %% [markdown]
# 1))It is a powerful and flexible library that provides a wide range of visualization options.

# %% [markdown]
# 2))It is easy to learn and use.

# %% [markdown]
# 3))It integrates well with other scientific computing libraries in Python such as NumPy, Pandas, and Scikit-Learn.

# %% [markdown]
# 4))It has a large and active community, which means that there are many resources and examples available online.

# %% [markdown]
# ^^Five plots that can be plotted using the Pyplot module of Matplotlib are:

# %% [markdown]
# (1) Line Plot: A line plot is a type of plot that displays data as a series of points connected by straight lines.

# %% [markdown]
# (2) Scatter Plot: A scatter plot is a type of plot that displays data as a collection of points.

# %% [markdown]
# (3) Histogram: A histogram is a type of plot that displays the distribution of a dataset.

# %% [markdown]
# (4) Bar Plot: A bar plot is a type of plot that displays the frequency or distribution of categorical data.

# %% [markdown]
# (5)Box Plot: A box plot is a type of plot that displays the distribution of a dataset based on the five-number summary (minimum, first quartile, median, third quartile, and maximum).

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.

# %%
#Note: Also add title, xlabel, and ylabel to the plot.
import matplotlib.pyplot as plot
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plot.scatter(x,y)
plot.xlabel("x lable")
plot.ylabel("y lable")
plot.title("random")
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:

# %%
import numpy as np
#plot 1
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([0, 100, 200, 300, 400, 500])
plot.subplot(2,3,1)
plot.plot(x,y)
plot.title("plot 1")
plot.show
 #plot2
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([50, 20, 40, 20, 60, 70])
plot.subplot(2,3,2)
plot.plot(x,y)
plot.title("plot 2")
plot.show
#plot3
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])
plot.subplot(2,3,3)
plot.plot(x,y)
plot.title("plot 3")
plot.show
#plot4
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])
plot.subplot(2,3,4)
plot.plot(x,y)
plot.title("plot 4")
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [markdown]
# A bar plot or bar chart is a graph that represents the category of data with rectangular bars with lengths and heights that is proportional to the values which they represent. The bar plots can be plotted horizontally or vertically.

# %% [markdown]
# USES---
# A bar chart describes the comparisons between the discrete categories. One of the axis of the plot represents the specific categories being compared, while the other axis represents the measured values corresponding to those categories.

# %%
import matplotlib.pyplot as plot
import numpy as np
data={'Apple':3000,'Microsoft': 8000,'Google':1000 ,'AMD':10000}
company=list(data.keys())
profit=list(data.values())
data
# Out:
# {'Apple': 3000, 'Microsoft': 8000, 'Google': 1000, 'AMD': 10000}

# %%
fig = plot.figure(figsize =(10 ,5))
plot.bar(company,profit,color='maroon',width=0.4)
plot.xlabel("Profit of company")
plot.ylabel("Company name ")
plot.title(" Total Profit bar chart")
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig = plot.figure(figsize =(10 ,5))
plot.barh(company,profit,color='maroon')
plot.xlabel("Profit of company")
plot.ylabel("Company name ")
plot.title(" Total Profit bar chart")
plot.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.

# %% [markdown]
# A box and whisker plot—also called a box plot—displays the five-number summary of a set of data. The five-number summary is the minimum, first quartile, median, third quartile, and maximum.

# %% [markdown]
# In a box plot, we draw a box from the first quartile to the third quartile. A vertical line goes through the box at the median. The whiskers go from each quartile to the minimum or maximum.

# %% [markdown]
# USES

# %% [markdown]
# Box plots provide a visual summary of the data with which we can quickly identify the average value of the data, how dispersed the data is, whether the data is skewed or not (skewness).

# %% [markdown]
# The Median gives you the average value of the data.

# %% [markdown]
# Box Plots shows Skewness of the data-

# %% [markdown]
# *a) If the Median is at the center of the Box and the whiskers are almost the
#    same on both the ends then the data is Normally Distributed.

# %% [markdown]
# *b) If the Median lies closer to the First Quartile and if the whisker at the lower
#    end is shorter (as in the above example) then it has a Positive Skew (Right Skew).

# %% [markdown]
# *c) If the Median lies closer to the Third Quartile and if the whisker at the
#    upper end is shorter then it has a Negative Skew (Left Skew).

# %%
import matplotlib.pyplot as plot
import numpy as np
np.random.seed(10)
data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data =[data_1,data_2]
fig = plot.figure(figsize = (5,3))
ax = fig.add_axes([0,0,1,1])
bp = ax.boxplot(data)
plot.title("BOX PLOT")
plot.show()
